# %%
import os
import sys

import gradio as gr
from dotenv import load_dotenv
from huggingface_hub import InferenceClient

sys.path.append(
    os.path.abspath(os.path.join(os.getcwd(), "..", "retrieval_pipeline"))
)
from retrieval_pipeline import retrieval_pipeline_url
# Out:
# `BlipModel` is going to be deprecated in future release, please use `BlipForConditionalGeneration`, `BlipForQuestionAnswering` or `BlipForImageTextRetrieval` depending on your usecase.
# Database Ready.
# Loading fine-tuned model
# ...

# %%
load_dotenv()
API_KEY = os.getenv("HF_TOKEN")
client = InferenceClient(
    provider="novita",
    api_key=API_KEY,
)

# %%
# -- LLM Call --
def query_llm(user_query, youtube_link, max_tokens=250):
    prompt = f"""The user is asking a question about a YouTube video.

Video Link: {youtube_link}
Question: {user_query}

Please help the user by answering their question based on the linked video. You may assume the video link points directly to the relevant part of the content."""

    try:
        # Call the Hugging Face API using the InferenceClient
        completion = client.chat.completions.create(
            model="deepseek-ai/DeepSeek-Prover-V2-671B",  # replace with the appropriate model
            messages=[{"role": "user", "content": prompt}],
            max_tokens=max_tokens,
        )
        # Extract the response text from the API response
        return completion.choices[0].message["content"]
    except Exception as e:
        return f"Error communicating with Hugging Face API: {e}"

# %% [markdown]
# ## Example 1
# query = "Using only the videos, explain how ResNets work."

# %%
from app import handle_query

# %% [markdown]
# ### Result from retrieval pipeline

# %%
query = "Using only the videos, explain how ResNets work."

# Returns unique top relevant videos given the query and selects the most relevant one or closest to its cosine
retrieval_pipeline_url(query)
# Out:
# 🔍 Searching for: Using only the videos, explain how ResNets work.
# Video ID: TV-DjM8242s, Timestamp: 3.0 - 3.0
# Video ID: TV-DjM8242s, Timestamp: 131.0 - 131.0
# Video ID: TV-DjM8242s, Timestamp: 77.0 - 77.0
# Video ID: eQ6UE968Xe4, Timestamp: 34.0 - 34.0
# Video ID: eQ6UE968Xe4, Timestamp: 2.0 - 2.0
# TV-DjM8242s
# 3.0
# 136.0
# 'https://www.youtube.com/embed/TV-DjM8242s?t=3.0'

# %%
query = "Using only the videos, explain the advantages of CNNs over fully connected networks."
# Returns unique top relevant videos given the query and selects the most relevant one or closest to its cosine
retrieval_pipeline_url(query)
# Out:
# 🔍 Searching for: Using only the videos, explain the advantages of CNNs over fully connected networks.
# Video ID: TV-DjM8242s, Timestamp: 79.0 - 79.0
# Video ID: eQ6UE968Xe4, Timestamp: 34.0 - 34.0
# Video ID: eQ6UE968Xe4, Timestamp: 2.0 - 2.0
# Video ID: eQ6UE968Xe4, Timestamp: 33.0 - 33.0
# Video ID: eQ6UE968Xe4, Timestamp: 30.0 - 30.0
# eQ6UE968Xe4
# 2.0
# 39.0
# 'https://www.youtube.com/embed/eQ6UE968Xe4?t=2.0'

# %%
query = "Using only the videos, explain the the binary cross entropy loss function."
# Returns unique top relevant videos given the query and selects the most relevant one or closest to its cosine
retrieval_pipeline_url(query)
# Out:
# 🔍 Searching for: Using only the videos, explain the the binary cross entropy loss function.
# Video ID: 9CGGh6ivg68, Timestamp: 3.0 - 3.0
# Video ID: TV-DjM8242s, Timestamp: 3.0 - 3.0
# Video ID: TV-DjM8242s, Timestamp: 74.0 - 74.0
# Video ID: eQ6UE968Xe4, Timestamp: 25.0 - 25.0
# Video ID: eQ6UE968Xe4, Timestamp: 29.0 - 29.0
# TV-DjM8242s
# 3.0
# 79.0
# 'https://www.youtube.com/embed/TV-DjM8242s?t=3.0'
